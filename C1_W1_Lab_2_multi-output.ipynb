# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 960us/sample - loss: 249.8614 - y1_output_loss: 114.4965 - y2_output_loss: 133.1559 - y1_output_root_mean_squared_error: 10.7492 - y2_output_root_mean_squared_error: 11.5895 - val_loss: 44.5245 - val_y1_output_loss: 14.1057 - val_y2_output_loss: 29.0733 - val_y1_output_root_mean_squared_error: 3.8234 - val_y2_output_root_mean_squared_error: 5.4687
# Epoch 2/500
# 614/614 [==============================] - 0s 154us/sample - loss: 39.0676 - y1_output_loss: 14.0406 - y2_output_loss: 25.0041 - y1_output_root_mean_squared_error: 3.7367 - y2_output_root_mean_squared_error: 5.0104 - val_loss: 17.9558 - val_y1_output_loss: 7.6821 - val_y2_output_loss: 9.9842 - val_y1_output_root_mean_squared_error: 2.7875 - val_y2_output_root_mean_squared_error: 3.1915
# Epoch 3/500
# 614/614 [==============================] - 0s 143us/sample - loss: 24.5245 - y1_output_loss: 10.1009 - y2_output_loss: 14.3256 - y1_output_root_mean_squared_error: 3.1900 - y2_output_root_mean_squared_error: 3.7879 - val_loss: 25.6525 - val_y1_output_loss: 8.8374 - val_y2_output_loss: 16.3315 - val_y1_output_root_mean_squared_error: 3.0078 - val_y2_output_root_mean_squared_error: 4.0750
# Epoch 4/500
# 614/614 [==============================] - 0s 140us/sample - loss: 25.9868 - y1_output_loss: 10.3186 - y2_output_loss: 15.4248 - y1_output_root_mean_squared_error: 3.2276 - y2_output_root_mean_squared_error: 3.9458 - val_loss: 19.5622 - val_y1_output_loss: 7.8202 - val_y2_output_loss: 11.1857 - val_y1_output_root_mean_squared_error: 2.8298 - val_y2_output_root_mean_squared_error: 3.3992
# Epoch 5/500
# 614/614 [==============================] - 0s 143us/sample - loss: 25.6986 - y1_output_loss: 9.8970 - y2_output_loss: 15.5709 - y1_output_root_mean_squared_error: 3.1596 - y2_output_root_mean_squared_error: 3.9643 - val_loss: 15.2319 - val_y1_output_loss: 6.5108 - val_y2_output_loss: 8.2260 - val_y1_output_root_mean_squared_error: 2.5951 - val_y2_output_root_mean_squared_error: 2.9151
# Epoch 6/500
# 614/614 [==============================] - 0s 134us/sample - loss: 23.1955 - y1_output_loss: 9.3249 - y2_output_loss: 13.7669 - y1_output_root_mean_squared_error: 3.0585 - y2_output_root_mean_squared_error: 3.7203 - val_loss: 17.2107 - val_y1_output_loss: 6.9122 - val_y2_output_loss: 9.8316 - val_y1_output_root_mean_squared_error: 2.6715 - val_y2_output_root_mean_squared_error: 3.1739
# Epoch 7/500
# 614/614 [==============================] - 0s 128us/sample - loss: 22.2073 - y1_output_loss: 9.1920 - y2_output_loss: 13.0962 - y1_output_root_mean_squared_error: 3.0351 - y2_output_root_mean_squared_error: 3.6049 - val_loss: 30.2454 - val_y1_output_loss: 8.7359 - val_y2_output_loss: 23.0114 - val_y1_output_root_mean_squared_error: 2.9404 - val_y2_output_root_mean_squared_error: 4.6475
# Epoch 8/500
# 614/614 [==============================] - 0s 137us/sample - loss: 22.7116 - y1_output_loss: 9.0195 - y2_output_loss: 13.6696 - y1_output_root_mean_squared_error: 2.9935 - y2_output_root_mean_squared_error: 3.7082 - val_loss: 19.0790 - val_y1_output_loss: 7.7197 - val_y2_output_loss: 11.0143 - val_y1_output_root_mean_squared_error: 2.8011 - val_y2_output_root_mean_squared_error: 3.3515
# Epoch 9/500
# 614/614 [==============================] - 0s 134us/sample - loss: 21.7674 - y1_output_loss: 8.7443 - y2_output_loss: 13.6844 - y1_output_root_mean_squared_error: 2.9402 - y2_output_root_mean_squared_error: 3.6226 - val_loss: 57.4997 - val_y1_output_loss: 11.4812 - val_y2_output_loss: 50.6078 - val_y1_output_root_mean_squared_error: 3.2977 - val_y2_output_root_mean_squared_error: 6.8282
# Epoch 10/500
# 614/614 [==============================] - 0s 140us/sample - loss: 23.7008 - y1_output_loss: 8.8159 - y2_output_loss: 15.0601 - y1_output_root_mean_squared_error: 2.9456 - y2_output_root_mean_squared_error: 3.8761 - val_loss: 56.4035 - val_y1_output_loss: 14.7109 - val_y2_output_loss: 42.6570 - val_y1_output_root_mean_squared_error: 3.8097 - val_y2_output_root_mean_squared_error: 6.4722
# Epoch 11/500
# 614/614 [==============================] - 0s 138us/sample - loss: 21.6837 - y1_output_loss: 7.9312 - y2_output_loss: 13.5709 - y1_output_root_mean_squared_error: 2.8267 - y2_output_root_mean_squared_error: 3.7005 - val_loss: 13.7312 - val_y1_output_loss: 5.6284 - val_y2_output_loss: 7.6281 - val_y1_output_root_mean_squared_error: 2.4150 - val_y2_output_root_mean_squared_error: 2.8105
# Epoch 12/500
# 614/614 [==============================] - 0s 125us/sample - loss: 23.3462 - y1_output_loss: 8.6140 - y2_output_loss: 14.7429 - y1_output_root_mean_squared_error: 2.9320 - y2_output_root_mean_squared_error: 3.8405 - val_loss: 25.8563 - val_y1_output_loss: 8.9621 - val_y2_output_loss: 16.8569 - val_y1_output_root_mean_squared_error: 2.9943 - val_y2_output_root_mean_squared_error: 4.1098
# Epoch 13/500
# 614/614 [==============================] - 0s 131us/sample - loss: 17.2979 - y1_output_loss: 7.1938 - y2_output_loss: 10.2772 - y1_output_root_mean_squared_error: 2.6837 - y2_output_root_mean_squared_error: 3.1774 - val_loss: 20.7843 - val_y1_output_loss: 6.9906 - val_y2_output_loss: 13.7913 - val_y1_output_root_mean_squared_error: 2.6746 - val_y2_output_root_mean_squared_error: 3.6920
# Epoch 14/500
# 614/614 [==============================] - 0s 138us/sample - loss: 19.0963 - y1_output_loss: 7.2072 - y2_output_loss: 12.0337 - y1_output_root_mean_squared_error: 2.6841 - y2_output_root_mean_squared_error: 3.4485 - val_loss: 24.5402 - val_y1_output_loss: 7.1558 - val_y2_output_loss: 17.8781 - val_y1_output_root_mean_squared_error: 2.6954 - val_y2_output_root_mean_squared_error: 4.1563
# Epoch 15/500
# 614/614 [==============================] - 0s 135us/sample - loss: 16.6213 - y1_output_loss: 6.7856 - y2_output_loss: 9.7580 - y1_output_root_mean_squared_error: 2.6141 - y2_output_root_mean_squared_error: 3.1285 - val_loss: 14.5808 - val_y1_output_loss: 5.9665 - val_y2_output_loss: 8.2118 - val_y1_output_root_mean_squared_error: 2.4756 - val_y2_output_root_mean_squared_error: 2.9073
# Epoch 16/500
# 614/614 [==============================] - 0s 141us/sample - loss: 16.5639 - y1_output_loss: 6.5044 - y2_output_loss: 9.9304 - y1_output_root_mean_squared_error: 2.5610 - y2_output_root_mean_squared_error: 3.1631 - val_loss: 12.7780 - val_y1_output_loss: 4.9171 - val_y2_output_loss: 7.5641 - val_y1_output_root_mean_squared_error: 2.2547 - val_y2_output_root_mean_squared_error: 2.7739
# Epoch 17/500
# 614/614 [==============================] - 0s 140us/sample - loss: 15.8134 - y1_output_loss: 6.1474 - y2_output_loss: 9.7769 - y1_output_root_mean_squared_error: 2.4696 - y2_output_root_mean_squared_error: 3.1168 - val_loss: 19.8572 - val_y1_output_loss: 7.1712 - val_y2_output_loss: 12.8702 - val_y1_output_root_mean_squared_error: 2.6660 - val_y2_output_root_mean_squared_error: 3.5707
# Epoch 18/500
# 614/614 [==============================] - 0s 135us/sample - loss: 15.5316 - y1_output_loss: 5.8906 - y2_output_loss: 9.6127 - y1_output_root_mean_squared_error: 2.4307 - y2_output_root_mean_squared_error: 3.1021 - val_loss: 15.0462 - val_y1_output_loss: 4.9435 - val_y2_output_loss: 9.9680 - val_y1_output_root_mean_squared_error: 2.2359 - val_y2_output_root_mean_squared_error: 3.1697
# Epoch 19/500
# 614/614 [==============================] - 0s 141us/sample - loss: 14.0394 - y1_output_loss: 5.4514 - y2_output_loss: 8.5313 - y1_output_root_mean_squared_error: 2.3334 - y2_output_root_mean_squared_error: 2.9317 - val_loss: 16.2211 - val_y1_output_loss: 6.4948 - val_y2_output_loss: 9.5398 - val_y1_output_root_mean_squared_error: 2.5564 - val_y2_output_root_mean_squared_error: 3.1122
# Epoch 20/500
# 614/614 [==============================] - 0s 125us/sample - loss: 16.7178 - y1_output_loss: 6.2346 - y2_output_loss: 10.5542 - y1_output_root_mean_squared_error: 2.5028 - y2_output_root_mean_squared_error: 3.2332 - val_loss: 15.5275 - val_y1_output_loss: 4.7322 - val_y2_output_loss: 10.7019 - val_y1_output_root_mean_squared_error: 2.2032 - val_y2_output_root_mean_squared_error: 3.2670
# Epoch 21/500
# 614/614 [==============================] - 0s 141us/sample - loss: 13.3019 - y1_output_loss: 5.2591 - y2_output_loss: 8.1113 - y1_output_root_mean_squared_error: 2.2969 - y2_output_root_mean_squared_error: 2.8331 - val_loss: 12.0770 - val_y1_output_loss: 4.8322 - val_y2_output_loss: 7.0211 - val_y1_output_root_mean_squared_error: 2.2156 - val_y2_output_root_mean_squared_error: 2.6773
# Epoch 22/500
# 614/614 [==============================] - 0s 133us/sample - loss: 13.6086 - y1_output_loss: 5.0219 - y2_output_loss: 8.5316 - y1_output_root_mean_squared_error: 2.2416 - y2_output_root_mean_squared_error: 2.9298 - val_loss: 9.1103 - val_y1_output_loss: 3.9120 - val_y2_output_loss: 5.0481 - val_y1_output_root_mean_squared_error: 1.9908 - val_y2_output_root_mean_squared_error: 2.2687
# Epoch 23/500
# 614/614 [==============================] - 0s 142us/sample - loss: 12.3449 - y1_output_loss: 4.8010 - y2_output_loss: 7.7823 - y1_output_root_mean_squared_error: 2.1668 - y2_output_root_mean_squared_error: 2.7658 - val_loss: 14.4147 - val_y1_output_loss: 6.3046 - val_y2_output_loss: 8.1512 - val_y1_output_root_mean_squared_error: 2.4937 - val_y2_output_root_mean_squared_error: 2.8629
# Epoch 24/500
# 614/614 [==============================] - 0s 135us/sample - loss: 12.7649 - y1_output_loss: 4.6699 - y2_output_loss: 7.9993 - y1_output_root_mean_squared_error: 2.1708 - y2_output_root_mean_squared_error: 2.8377 - val_loss: 8.4467 - val_y1_output_loss: 3.6440 - val_y2_output_loss: 4.5295 - val_y1_output_root_mean_squared_error: 1.9389 - val_y2_output_root_mean_squared_error: 2.1650
# Epoch 25/500
# 614/614 [==============================] - 0s 123us/sample - loss: 11.2179 - y1_output_loss: 4.3090 - y2_output_loss: 6.8475 - y1_output_root_mean_squared_error: 2.0787 - y2_output_root_mean_squared_error: 2.6262 - val_loss: 8.6501 - val_y1_output_loss: 3.7768 - val_y2_output_loss: 4.7598 - val_y1_output_root_mean_squared_error: 1.9469 - val_y2_output_root_mean_squared_error: 2.2045
# Epoch 26/500
# 614/614 [==============================] - 0s 135us/sample - loss: 13.8360 - y1_output_loss: 4.8090 - y2_output_loss: 8.8979 - y1_output_root_mean_squared_error: 2.2028 - y2_output_root_mean_squared_error: 2.9973 - val_loss: 8.9741 - val_y1_output_loss: 3.5914 - val_y2_output_loss: 5.1458 - val_y1_output_root_mean_squared_error: 1.9177 - val_y2_output_root_mean_squared_error: 2.3014
# Epoch 27/500
# 614/614 [==============================] - 0s 146us/sample - loss: 11.6261 - y1_output_loss: 4.1338 - y2_output_loss: 7.4641 - y1_output_root_mean_squared_error: 2.0390 - y2_output_root_mean_squared_error: 2.7329 - val_loss: 12.1032 - val_y1_output_loss: 4.0783 - val_y2_output_loss: 8.1310 - val_y1_output_root_mean_squared_error: 2.0409 - val_y2_output_root_mean_squared_error: 2.8174
# Epoch 28/500
# 614/614 [==============================] - 0s 136us/sample - loss: 15.7148 - y1_output_loss: 5.4121 - y2_output_loss: 10.2186 - y1_output_root_mean_squared_error: 2.3347 - y2_output_root_mean_squared_error: 3.2038 - val_loss: 8.2636 - val_y1_output_loss: 3.7698 - val_y2_output_loss: 4.3663 - val_y1_output_root_mean_squared_error: 1.9601 - val_y2_output_root_mean_squared_error: 2.1028
# Epoch 29/500
# 614/614 [==============================] - 0s 139us/sample - loss: 10.2390 - y1_output_loss: 3.6829 - y2_output_loss: 6.6141 - y1_output_root_mean_squared_error: 1.9195 - y2_output_root_mean_squared_error: 2.5602 - val_loss: 8.1247 - val_y1_output_loss: 3.1987 - val_y2_output_loss: 4.7119 - val_y1_output_root_mean_squared_error: 1.8171 - val_y2_output_root_mean_squared_error: 2.1961
# Epoch 30/500
# 614/614 [==============================] - 0s 135us/sample - loss: 9.5451 - y1_output_loss: 3.5810 - y2_output_loss: 6.0409 - y1_output_root_mean_squared_error: 1.8887 - y2_output_root_mean_squared_error: 2.4450 - val_loss: 8.5065 - val_y1_output_loss: 3.3383 - val_y2_output_loss: 4.9331 - val_y1_output_root_mean_squared_error: 1.8504 - val_y2_output_root_mean_squared_error: 2.2544
# Epoch 31/500
# 614/614 [==============================] - 0s 134us/sample - loss: 15.3660 - y1_output_loss: 4.7748 - y2_output_loss: 10.4631 - y1_output_root_mean_squared_error: 2.1930 - y2_output_root_mean_squared_error: 3.2491 - val_loss: 11.3754 - val_y1_output_loss: 3.6396 - val_y2_output_loss: 7.4997 - val_y1_output_root_mean_squared_error: 1.9312 - val_y2_output_root_mean_squared_error: 2.7651
# Epoch 32/500
# 614/614 [==============================] - 0s 120us/sample - loss: 8.9958 - y1_output_loss: 3.2135 - y2_output_loss: 5.7028 - y1_output_root_mean_squared_error: 1.7999 - y2_output_root_mean_squared_error: 2.3992 - val_loss: 6.5658 - val_y1_output_loss: 2.7636 - val_y2_output_loss: 3.6472 - val_y1_output_root_mean_squared_error: 1.6744 - val_y2_output_root_mean_squared_error: 1.9396
# Epoch 33/500
# 614/614 [==============================] - 0s 145us/sample - loss: 8.6647 - y1_output_loss: 3.1388 - y2_output_loss: 5.6032 - y1_output_root_mean_squared_error: 1.7660 - y2_output_root_mean_squared_error: 2.3550 - val_loss: 5.8306 - val_y1_output_loss: 2.3678 - val_y2_output_loss: 3.2701 - val_y1_output_root_mean_squared_error: 1.5673 - val_y2_output_root_mean_squared_error: 1.8369
# Epoch 34/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.8306 - y1_output_loss: 3.5283 - y2_output_loss: 7.2888 - y1_output_root_mean_squared_error: 1.8853 - y2_output_root_mean_squared_error: 2.6974 - val_loss: 7.3851 - val_y1_output_loss: 2.6341 - val_y2_output_loss: 4.7048 - val_y1_output_root_mean_squared_error: 1.6431 - val_y2_output_root_mean_squared_error: 2.1646
# Epoch 35/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.1540 - y1_output_loss: 3.0510 - y2_output_loss: 6.0776 - y1_output_root_mean_squared_error: 1.7545 - y2_output_root_mean_squared_error: 2.4649 - val_loss: 9.3763 - val_y1_output_loss: 2.8777 - val_y2_output_loss: 6.5018 - val_y1_output_root_mean_squared_error: 1.7218 - val_y2_output_root_mean_squared_error: 2.5322
# Epoch 36/500
# 614/614 [==============================] - 0s 139us/sample - loss: 10.3274 - y1_output_loss: 3.4639 - y2_output_loss: 6.8248 - y1_output_root_mean_squared_error: 1.8682 - y2_output_root_mean_squared_error: 2.6148 - val_loss: 12.9018 - val_y1_output_loss: 4.0144 - val_y2_output_loss: 9.9821 - val_y1_output_root_mean_squared_error: 1.9610 - val_y2_output_root_mean_squared_error: 3.0094
# Epoch 37/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.0933 - y1_output_loss: 3.5475 - y2_output_loss: 8.4620 - y1_output_root_mean_squared_error: 1.8904 - y2_output_root_mean_squared_error: 2.9189 - val_loss: 8.8978 - val_y1_output_loss: 3.2563 - val_y2_output_loss: 5.4101 - val_y1_output_root_mean_squared_error: 1.8238 - val_y2_output_root_mean_squared_error: 2.3604
# Epoch 38/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.1494 - y1_output_loss: 2.8857 - y2_output_loss: 5.3137 - y1_output_root_mean_squared_error: 1.6823 - y2_output_root_mean_squared_error: 2.3064 - val_loss: 12.3090 - val_y1_output_loss: 3.3702 - val_y2_output_loss: 8.7530 - val_y1_output_root_mean_squared_error: 1.8542 - val_y2_output_root_mean_squared_error: 2.9784
# Epoch 39/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.5997 - y1_output_loss: 3.0426 - y2_output_loss: 5.6478 - y1_output_root_mean_squared_error: 1.7407 - y2_output_root_mean_squared_error: 2.3600 - val_loss: 23.0073 - val_y1_output_loss: 8.4296 - val_y2_output_loss: 16.4676 - val_y1_output_root_mean_squared_error: 2.7437 - val_y2_output_root_mean_squared_error: 3.9344
# Epoch 40/500
# 614/614 [==============================] - 0s 140us/sample - loss: 8.8312 - y1_output_loss: 2.9611 - y2_output_loss: 5.8264 - y1_output_root_mean_squared_error: 1.7234 - y2_output_root_mean_squared_error: 2.4210 - val_loss: 7.0352 - val_y1_output_loss: 2.9250 - val_y2_output_loss: 3.9162 - val_y1_output_root_mean_squared_error: 1.7324 - val_y2_output_root_mean_squared_error: 2.0085
# Epoch 41/500
# 614/614 [==============================] - 0s 141us/sample - loss: 8.1749 - y1_output_loss: 2.7603 - y2_output_loss: 5.4556 - y1_output_root_mean_squared_error: 1.6570 - y2_output_root_mean_squared_error: 2.3301 - val_loss: 7.0388 - val_y1_output_loss: 2.3134 - val_y2_output_loss: 4.9556 - val_y1_output_root_mean_squared_error: 1.5271 - val_y2_output_root_mean_squared_error: 2.1695
# Epoch 42/500
# 614/614 [==============================] - 0s 143us/sample - loss: 9.2292 - y1_output_loss: 2.7679 - y2_output_loss: 6.6082 - y1_output_root_mean_squared_error: 1.6473 - y2_output_root_mean_squared_error: 2.5526 - val_loss: 16.9640 - val_y1_output_loss: 4.0971 - val_y2_output_loss: 12.9329 - val_y1_output_root_mean_squared_error: 2.0203 - val_y2_output_root_mean_squared_error: 3.5892
# Epoch 43/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.3754 - y1_output_loss: 2.5462 - y2_output_loss: 4.8656 - y1_output_root_mean_squared_error: 1.5990 - y2_output_root_mean_squared_error: 2.1951 - val_loss: 6.6695 - val_y1_output_loss: 2.4539 - val_y2_output_loss: 4.0856 - val_y1_output_root_mean_squared_error: 1.5763 - val_y2_output_root_mean_squared_error: 2.0457
# Epoch 44/500
# 614/614 [==============================] - 0s 126us/sample - loss: 7.1913 - y1_output_loss: 2.3180 - y2_output_loss: 4.8703 - y1_output_root_mean_squared_error: 1.5255 - y2_output_root_mean_squared_error: 2.2055 - val_loss: 6.0329 - val_y1_output_loss: 2.2432 - val_y2_output_loss: 3.9815 - val_y1_output_root_mean_squared_error: 1.4923 - val_y2_output_root_mean_squared_error: 1.9509
# Epoch 45/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.2206 - y1_output_loss: 2.4904 - y2_output_loss: 4.7580 - y1_output_root_mean_squared_error: 1.5676 - y2_output_root_mean_squared_error: 2.1825 - val_loss: 13.8168 - val_y1_output_loss: 6.0654 - val_y2_output_loss: 8.8285 - val_y1_output_root_mean_squared_error: 2.3855 - val_y2_output_root_mean_squared_error: 2.8507
# Epoch 46/500
# 614/614 [==============================] - 0s 139us/sample - loss: 10.0882 - y1_output_loss: 3.2900 - y2_output_loss: 6.7178 - y1_output_root_mean_squared_error: 1.8205 - y2_output_root_mean_squared_error: 2.6027 - val_loss: 6.3949 - val_y1_output_loss: 2.3938 - val_y2_output_loss: 3.8542 - val_y1_output_root_mean_squared_error: 1.5678 - val_y2_output_root_mean_squared_error: 1.9841
# Epoch 47/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.7902 - y1_output_loss: 2.4720 - y2_output_loss: 5.3957 - y1_output_root_mean_squared_error: 1.5762 - y2_output_root_mean_squared_error: 2.3034 - val_loss: 8.0220 - val_y1_output_loss: 2.2949 - val_y2_output_loss: 5.5342 - val_y1_output_root_mean_squared_error: 1.5350 - val_y2_output_root_mean_squared_error: 2.3803
# Epoch 48/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.5343 - y1_output_loss: 2.1620 - y2_output_loss: 4.3287 - y1_output_root_mean_squared_error: 1.4760 - y2_output_root_mean_squared_error: 2.0871 - val_loss: 10.4318 - val_y1_output_loss: 3.6480 - val_y2_output_loss: 6.9679 - val_y1_output_root_mean_squared_error: 1.8843 - val_y2_output_root_mean_squared_error: 2.6232
# Epoch 49/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.9091 - y1_output_loss: 3.2911 - y2_output_loss: 6.5577 - y1_output_root_mean_squared_error: 1.8186 - y2_output_root_mean_squared_error: 2.5694 - val_loss: 4.8067 - val_y1_output_loss: 1.9041 - val_y2_output_loss: 2.8469 - val_y1_output_root_mean_squared_error: 1.4000 - val_y2_output_root_mean_squared_error: 1.6872
# Epoch 50/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.6906 - y1_output_loss: 2.5352 - y2_output_loss: 5.0852 - y1_output_root_mean_squared_error: 1.5994 - y2_output_root_mean_squared_error: 2.2655 - val_loss: 6.8278 - val_y1_output_loss: 2.3676 - val_y2_output_loss: 4.2538 - val_y1_output_root_mean_squared_error: 1.5615 - val_y2_output_root_mean_squared_error: 2.0951
# Epoch 51/500
# 614/614 [==============================] - 0s 122us/sample - loss: 8.2775 - y1_output_loss: 2.5542 - y2_output_loss: 5.6991 - y1_output_root_mean_squared_error: 1.5970 - y2_output_root_mean_squared_error: 2.3931 - val_loss: 6.1340 - val_y1_output_loss: 2.5543 - val_y2_output_loss: 3.6524 - val_y1_output_root_mean_squared_error: 1.5864 - val_y2_output_root_mean_squared_error: 1.9019
# Epoch 52/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.1973 - y1_output_loss: 2.3834 - y2_output_loss: 4.7901 - y1_output_root_mean_squared_error: 1.5505 - y2_output_root_mean_squared_error: 2.1893 - val_loss: 8.4873 - val_y1_output_loss: 2.5560 - val_y2_output_loss: 6.0576 - val_y1_output_root_mean_squared_error: 1.5761 - val_y2_output_root_mean_squared_error: 2.4501
# Epoch 53/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.2668 - y1_output_loss: 2.6925 - y2_output_loss: 5.6994 - y1_output_root_mean_squared_error: 1.6345 - y2_output_root_mean_squared_error: 2.3654 - val_loss: 28.2511 - val_y1_output_loss: 8.0776 - val_y2_output_loss: 21.7227 - val_y1_output_root_mean_squared_error: 2.7340 - val_y2_output_root_mean_squared_error: 4.5581
# Epoch 54/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.9498 - y1_output_loss: 3.1678 - y2_output_loss: 6.7700 - y1_output_root_mean_squared_error: 1.7780 - y2_output_root_mean_squared_error: 2.6055 - val_loss: 5.1095 - val_y1_output_loss: 1.8359 - val_y2_output_loss: 3.3584 - val_y1_output_root_mean_squared_error: 1.3599 - val_y2_output_root_mean_squared_error: 1.8056
# Epoch 55/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.8441 - y1_output_loss: 2.4929 - y2_output_loss: 5.2826 - y1_output_root_mean_squared_error: 1.5859 - y2_output_root_mean_squared_error: 2.3085 - val_loss: 4.5274 - val_y1_output_loss: 1.9573 - val_y2_output_loss: 2.6232 - val_y1_output_root_mean_squared_error: 1.3831 - val_y2_output_root_mean_squared_error: 1.6169
# Epoch 56/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.6137 - y1_output_loss: 2.4016 - y2_output_loss: 5.3764 - y1_output_root_mean_squared_error: 1.5152 - y2_output_root_mean_squared_error: 2.3061 - val_loss: 27.3899 - val_y1_output_loss: 9.7194 - val_y2_output_loss: 17.1348 - val_y1_output_root_mean_squared_error: 3.1400 - val_y2_output_root_mean_squared_error: 4.1869
# Epoch 57/500
# 614/614 [==============================] - 0s 125us/sample - loss: 8.0853 - y1_output_loss: 2.5399 - y2_output_loss: 5.4993 - y1_output_root_mean_squared_error: 1.5939 - y2_output_root_mean_squared_error: 2.3548 - val_loss: 6.1349 - val_y1_output_loss: 2.2372 - val_y2_output_loss: 3.9582 - val_y1_output_root_mean_squared_error: 1.4760 - val_y2_output_root_mean_squared_error: 1.9890
# Epoch 58/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.4833 - y1_output_loss: 2.0296 - y2_output_loss: 4.4213 - y1_output_root_mean_squared_error: 1.4265 - y2_output_root_mean_squared_error: 2.1091 - val_loss: 5.6967 - val_y1_output_loss: 1.8200 - val_y2_output_loss: 3.7748 - val_y1_output_root_mean_squared_error: 1.3571 - val_y2_output_root_mean_squared_error: 1.9634
# Epoch 59/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.7201 - y1_output_loss: 2.1690 - y2_output_loss: 4.7427 - y1_output_root_mean_squared_error: 1.4483 - y2_output_root_mean_squared_error: 2.1500 - val_loss: 27.9093 - val_y1_output_loss: 7.3780 - val_y2_output_loss: 20.9713 - val_y1_output_root_mean_squared_error: 2.6797 - val_y2_output_root_mean_squared_error: 4.5529
# Epoch 60/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.3327 - y1_output_loss: 2.1974 - y2_output_loss: 5.1125 - y1_output_root_mean_squared_error: 1.4841 - y2_output_root_mean_squared_error: 2.2650 - val_loss: 10.3510 - val_y1_output_loss: 2.5770 - val_y2_output_loss: 7.8493 - val_y1_output_root_mean_squared_error: 1.5833 - val_y2_output_root_mean_squared_error: 2.8008
# Epoch 61/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.3898 - y1_output_loss: 1.7957 - y2_output_loss: 3.5490 - y1_output_root_mean_squared_error: 1.3455 - y2_output_root_mean_squared_error: 1.8920 - val_loss: 5.6837 - val_y1_output_loss: 1.8105 - val_y2_output_loss: 3.8357 - val_y1_output_root_mean_squared_error: 1.3413 - val_y2_output_root_mean_squared_error: 1.9710
# Epoch 62/500
# 614/614 [==============================] - 0s 120us/sample - loss: 6.8149 - y1_output_loss: 2.1540 - y2_output_loss: 4.9986 - y1_output_root_mean_squared_error: 1.4281 - y2_output_root_mean_squared_error: 2.1853 - val_loss: 35.5513 - val_y1_output_loss: 9.2576 - val_y2_output_loss: 26.3734 - val_y1_output_root_mean_squared_error: 3.0391 - val_y2_output_root_mean_squared_error: 5.1298
# Epoch 63/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.8216 - y1_output_loss: 2.5010 - y2_output_loss: 5.3022 - y1_output_root_mean_squared_error: 1.5878 - y2_output_root_mean_squared_error: 2.3023 - val_loss: 13.9007 - val_y1_output_loss: 2.1648 - val_y2_output_loss: 11.8627 - val_y1_output_root_mean_squared_error: 1.4633 - val_y2_output_root_mean_squared_error: 3.4292
# Epoch 64/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.7565 - y1_output_loss: 1.9809 - y2_output_loss: 4.7505 - y1_output_root_mean_squared_error: 1.4049 - y2_output_root_mean_squared_error: 2.1870 - val_loss: 5.5076 - val_y1_output_loss: 1.9430 - val_y2_output_loss: 3.5091 - val_y1_output_root_mean_squared_error: 1.3927 - val_y2_output_root_mean_squared_error: 1.8889
# Epoch 65/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.5420 - y1_output_loss: 1.9832 - y2_output_loss: 4.5231 - y1_output_root_mean_squared_error: 1.4073 - y2_output_root_mean_squared_error: 2.1358 - val_loss: 4.7220 - val_y1_output_loss: 1.8257 - val_y2_output_loss: 2.8742 - val_y1_output_root_mean_squared_error: 1.3425 - val_y2_output_root_mean_squared_error: 1.7087
# Epoch 66/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.1791 - y1_output_loss: 1.5688 - y2_output_loss: 3.5710 - y1_output_root_mean_squared_error: 1.2568 - y2_output_root_mean_squared_error: 1.8973 - val_loss: 3.7941 - val_y1_output_loss: 1.3921 - val_y2_output_loss: 2.4109 - val_y1_output_root_mean_squared_error: 1.1863 - val_y2_output_root_mean_squared_error: 1.5449
# Epoch 67/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.0238 - y1_output_loss: 1.2743 - y2_output_loss: 2.7354 - y1_output_root_mean_squared_error: 1.1310 - y2_output_root_mean_squared_error: 1.6567 - val_loss: 4.1828 - val_y1_output_loss: 1.3129 - val_y2_output_loss: 2.9369 - val_y1_output_root_mean_squared_error: 1.1588 - val_y2_output_root_mean_squared_error: 1.6852
# Epoch 68/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.5221 - y1_output_loss: 1.9747 - y2_output_loss: 4.5250 - y1_output_root_mean_squared_error: 1.4105 - y2_output_root_mean_squared_error: 2.1290 - val_loss: 3.2366 - val_y1_output_loss: 1.2435 - val_y2_output_loss: 1.9402 - val_y1_output_root_mean_squared_error: 1.1203 - val_y2_output_root_mean_squared_error: 1.4077
# Epoch 69/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.2065 - y1_output_loss: 1.2550 - y2_output_loss: 2.9470 - y1_output_root_mean_squared_error: 1.1243 - y2_output_root_mean_squared_error: 1.7154 - val_loss: 4.1095 - val_y1_output_loss: 1.3873 - val_y2_output_loss: 2.6754 - val_y1_output_root_mean_squared_error: 1.1828 - val_y2_output_root_mean_squared_error: 1.6463
# Epoch 70/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.0944 - y1_output_loss: 1.7844 - y2_output_loss: 5.2949 - y1_output_root_mean_squared_error: 1.3375 - y2_output_root_mean_squared_error: 2.3033 - val_loss: 4.3650 - val_y1_output_loss: 1.5670 - val_y2_output_loss: 2.7482 - val_y1_output_root_mean_squared_error: 1.2417 - val_y2_output_root_mean_squared_error: 1.6802
# Epoch 71/500
# 614/614 [==============================] - 0s 136us/sample - loss: 9.5344 - y1_output_loss: 3.3981 - y2_output_loss: 6.1643 - y1_output_root_mean_squared_error: 1.8291 - y2_output_root_mean_squared_error: 2.4877 - val_loss: 18.4587 - val_y1_output_loss: 6.5601 - val_y2_output_loss: 13.3410 - val_y1_output_root_mean_squared_error: 2.4071 - val_y2_output_root_mean_squared_error: 3.5587
# Epoch 72/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.2123 - y1_output_loss: 1.3565 - y2_output_loss: 2.8282 - y1_output_root_mean_squared_error: 1.1702 - y2_output_root_mean_squared_error: 1.6861 - val_loss: 6.3555 - val_y1_output_loss: 2.3670 - val_y2_output_loss: 4.2304 - val_y1_output_root_mean_squared_error: 1.4778 - val_y2_output_root_mean_squared_error: 2.0424
# Epoch 73/500
# 614/614 [==============================] - 0s 122us/sample - loss: 4.0514 - y1_output_loss: 1.1274 - y2_output_loss: 2.8910 - y1_output_root_mean_squared_error: 1.0651 - y2_output_root_mean_squared_error: 1.7079 - val_loss: 2.9787 - val_y1_output_loss: 1.0130 - val_y2_output_loss: 1.8809 - val_y1_output_root_mean_squared_error: 1.0216 - val_y2_output_root_mean_squared_error: 1.3911
# Epoch 74/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.0374 - y1_output_loss: 1.1670 - y2_output_loss: 2.8734 - y1_output_root_mean_squared_error: 1.0790 - y2_output_root_mean_squared_error: 1.6950 - val_loss: 3.5466 - val_y1_output_loss: 1.0837 - val_y2_output_loss: 2.5488 - val_y1_output_root_mean_squared_error: 1.0511 - val_y2_output_root_mean_squared_error: 1.5626
# Epoch 75/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.2403 - y1_output_loss: 1.4036 - y2_output_loss: 3.8334 - y1_output_root_mean_squared_error: 1.1803 - y2_output_root_mean_squared_error: 1.9614 - val_loss: 2.8976 - val_y1_output_loss: 1.0774 - val_y2_output_loss: 1.8052 - val_y1_output_root_mean_squared_error: 1.0388 - val_y2_output_root_mean_squared_error: 1.3485
# Epoch 76/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.9842 - y1_output_loss: 1.0862 - y2_output_loss: 2.9034 - y1_output_root_mean_squared_error: 1.0368 - y2_output_root_mean_squared_error: 1.7056 - val_loss: 7.1659 - val_y1_output_loss: 1.3090 - val_y2_output_loss: 5.7540 - val_y1_output_root_mean_squared_error: 1.1546 - val_y2_output_root_mean_squared_error: 2.4151
# Epoch 77/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.4572 - y1_output_loss: 0.9674 - y2_output_loss: 2.5403 - y1_output_root_mean_squared_error: 0.9860 - y2_output_root_mean_squared_error: 1.5764 - val_loss: 4.5999 - val_y1_output_loss: 1.3081 - val_y2_output_loss: 3.6752 - val_y1_output_root_mean_squared_error: 1.1367 - val_y2_output_root_mean_squared_error: 1.8188
# Epoch 78/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.1231 - y1_output_loss: 2.2430 - y2_output_loss: 5.8494 - y1_output_root_mean_squared_error: 1.5038 - y2_output_root_mean_squared_error: 2.4211 - val_loss: 3.6473 - val_y1_output_loss: 1.1705 - val_y2_output_loss: 2.6241 - val_y1_output_root_mean_squared_error: 1.0746 - val_y2_output_root_mean_squared_error: 1.5788
# Epoch 79/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.6222 - y1_output_loss: 0.9765 - y2_output_loss: 2.6232 - y1_output_root_mean_squared_error: 0.9887 - y2_output_root_mean_squared_error: 1.6263 - val_loss: 3.5047 - val_y1_output_loss: 1.1095 - val_y2_output_loss: 2.3469 - val_y1_output_root_mean_squared_error: 1.0450 - val_y2_output_root_mean_squared_error: 1.5533
# Epoch 80/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.0096 - y1_output_loss: 1.1264 - y2_output_loss: 2.8515 - y1_output_root_mean_squared_error: 1.0658 - y2_output_root_mean_squared_error: 1.6952 - val_loss: 4.8078 - val_y1_output_loss: 1.7716 - val_y2_output_loss: 3.1247 - val_y1_output_root_mean_squared_error: 1.2963 - val_y2_output_root_mean_squared_error: 1.7685
# Epoch 81/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.7855 - y1_output_loss: 1.6374 - y2_output_loss: 3.1826 - y1_output_root_mean_squared_error: 1.2661 - y2_output_root_mean_squared_error: 1.7840 - val_loss: 6.3764 - val_y1_output_loss: 2.5664 - val_y2_output_loss: 4.0404 - val_y1_output_root_mean_squared_error: 1.5480 - val_y2_output_root_mean_squared_error: 1.9950
# Epoch 82/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.1643 - y1_output_loss: 0.8077 - y2_output_loss: 2.3318 - y1_output_root_mean_squared_error: 0.9023 - y2_output_root_mean_squared_error: 1.5330 - val_loss: 3.4519 - val_y1_output_loss: 0.7626 - val_y2_output_loss: 2.6105 - val_y1_output_root_mean_squared_error: 0.8826 - val_y2_output_root_mean_squared_error: 1.6349
# Epoch 83/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.2668 - y1_output_loss: 0.8306 - y2_output_loss: 2.4240 - y1_output_root_mean_squared_error: 0.9105 - y2_output_root_mean_squared_error: 1.5613 - val_loss: 3.6706 - val_y1_output_loss: 0.8838 - val_y2_output_loss: 2.7203 - val_y1_output_root_mean_squared_error: 0.9473 - val_y2_output_root_mean_squared_error: 1.6653
# Epoch 84/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.5049 - y1_output_loss: 0.8590 - y2_output_loss: 2.6522 - y1_output_root_mean_squared_error: 0.9276 - y2_output_root_mean_squared_error: 1.6262 - val_loss: 5.0599 - val_y1_output_loss: 0.7639 - val_y2_output_loss: 4.2400 - val_y1_output_root_mean_squared_error: 0.8728 - val_y2_output_root_mean_squared_error: 2.0732
# Epoch 85/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.6885 - y1_output_loss: 0.9717 - y2_output_loss: 2.7495 - y1_output_root_mean_squared_error: 0.9787 - y2_output_root_mean_squared_error: 1.6525 - val_loss: 8.7520 - val_y1_output_loss: 3.5564 - val_y2_output_loss: 6.8564 - val_y1_output_root_mean_squared_error: 1.7324 - val_y2_output_root_mean_squared_error: 2.3981
# Epoch 86/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.8517 - y1_output_loss: 1.4557 - y2_output_loss: 3.3838 - y1_output_root_mean_squared_error: 1.2100 - y2_output_root_mean_squared_error: 1.8406 - val_loss: 4.6412 - val_y1_output_loss: 1.3148 - val_y2_output_loss: 3.8137 - val_y1_output_root_mean_squared_error: 1.1014 - val_y2_output_root_mean_squared_error: 1.8515
# Epoch 87/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.8999 - y1_output_loss: 0.8046 - y2_output_loss: 2.0775 - y1_output_root_mean_squared_error: 0.8970 - y2_output_root_mean_squared_error: 1.4476 - val_loss: 2.1892 - val_y1_output_loss: 0.7415 - val_y2_output_loss: 1.4306 - val_y1_output_root_mean_squared_error: 0.8670 - val_y2_output_root_mean_squared_error: 1.1990
# Epoch 88/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.2531 - y1_output_loss: 0.9969 - y2_output_loss: 2.2554 - y1_output_root_mean_squared_error: 0.9968 - y2_output_root_mean_squared_error: 1.5032 - val_loss: 2.7900 - val_y1_output_loss: 0.7557 - val_y2_output_loss: 1.9943 - val_y1_output_root_mean_squared_error: 0.8803 - val_y2_output_root_mean_squared_error: 1.4195
# Epoch 89/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.2018 - y1_output_loss: 0.7997 - y2_output_loss: 2.4108 - y1_output_root_mean_squared_error: 0.8973 - y2_output_root_mean_squared_error: 1.5481 - val_loss: 3.1745 - val_y1_output_loss: 0.7584 - val_y2_output_loss: 2.3277 - val_y1_output_root_mean_squared_error: 0.8816 - val_y2_output_root_mean_squared_error: 1.5483
# Epoch 90/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.5360 - y1_output_loss: 0.6324 - y2_output_loss: 1.8959 - y1_output_root_mean_squared_error: 0.7956 - y2_output_root_mean_squared_error: 1.3795 - val_loss: 2.4123 - val_y1_output_loss: 0.6052 - val_y2_output_loss: 1.7268 - val_y1_output_root_mean_squared_error: 0.7922 - val_y2_output_root_mean_squared_error: 1.3360
# Epoch 91/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.1138 - y1_output_loss: 0.8673 - y2_output_loss: 2.2197 - y1_output_root_mean_squared_error: 0.9353 - y2_output_root_mean_squared_error: 1.4963 - val_loss: 2.9018 - val_y1_output_loss: 0.9684 - val_y2_output_loss: 1.9130 - val_y1_output_root_mean_squared_error: 0.9662 - val_y2_output_root_mean_squared_error: 1.4030
# Epoch 92/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.5243 - y1_output_loss: 0.7383 - y2_output_loss: 1.7777 - y1_output_root_mean_squared_error: 0.8620 - y2_output_root_mean_squared_error: 1.3347 - val_loss: 3.0223 - val_y1_output_loss: 0.8773 - val_y2_output_loss: 2.1047 - val_y1_output_root_mean_squared_error: 0.9287 - val_y2_output_root_mean_squared_error: 1.4696
# Epoch 93/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.5948 - y1_output_loss: 0.6861 - y2_output_loss: 1.8997 - y1_output_root_mean_squared_error: 0.8281 - y2_output_root_mean_squared_error: 1.3817 - val_loss: 2.4623 - val_y1_output_loss: 0.9106 - val_y2_output_loss: 1.5596 - val_y1_output_root_mean_squared_error: 0.9340 - val_y2_output_root_mean_squared_error: 1.2609
# Epoch 94/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.1361 - y1_output_loss: 0.6216 - y2_output_loss: 1.5275 - y1_output_root_mean_squared_error: 0.7834 - y2_output_root_mean_squared_error: 1.2338 - val_loss: 5.5185 - val_y1_output_loss: 1.7112 - val_y2_output_loss: 3.8731 - val_y1_output_root_mean_squared_error: 1.2767 - val_y2_output_root_mean_squared_error: 1.9719
# Epoch 95/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.5938 - y1_output_loss: 0.6775 - y2_output_loss: 1.9040 - y1_output_root_mean_squared_error: 0.8252 - y2_output_root_mean_squared_error: 1.3830 - val_loss: 3.5379 - val_y1_output_loss: 0.4710 - val_y2_output_loss: 2.9740 - val_y1_output_root_mean_squared_error: 0.6983 - val_y2_output_root_mean_squared_error: 1.7465
# Epoch 96/500
# 614/614 [==============================] - 0s 121us/sample - loss: 4.6073 - y1_output_loss: 1.2806 - y2_output_loss: 3.3245 - y1_output_root_mean_squared_error: 1.1348 - y2_output_root_mean_squared_error: 1.8220 - val_loss: 7.1078 - val_y1_output_loss: 1.6424 - val_y2_output_loss: 5.9933 - val_y1_output_root_mean_squared_error: 1.1862 - val_y2_output_root_mean_squared_error: 2.3876
# Epoch 97/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.3850 - y1_output_loss: 1.1256 - y2_output_loss: 3.2379 - y1_output_root_mean_squared_error: 1.0620 - y2_output_root_mean_squared_error: 1.8048 - val_loss: 2.5701 - val_y1_output_loss: 0.7274 - val_y2_output_loss: 1.7986 - val_y1_output_root_mean_squared_error: 0.8611 - val_y2_output_root_mean_squared_error: 1.3522
# Epoch 98/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.2555 - y1_output_loss: 0.8696 - y2_output_loss: 2.3665 - y1_output_root_mean_squared_error: 0.9333 - y2_output_root_mean_squared_error: 1.5441 - val_loss: 2.1437 - val_y1_output_loss: 0.5440 - val_y2_output_loss: 1.6335 - val_y1_output_root_mean_squared_error: 0.7414 - val_y2_output_root_mean_squared_error: 1.2626
# Epoch 99/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.2670 - y1_output_loss: 0.7663 - y2_output_loss: 2.5128 - y1_output_root_mean_squared_error: 0.8762 - y2_output_root_mean_squared_error: 1.5809 - val_loss: 4.7220 - val_y1_output_loss: 1.0263 - val_y2_output_loss: 3.8177 - val_y1_output_root_mean_squared_error: 0.9960 - val_y2_output_root_mean_squared_error: 1.9313
# Epoch 100/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.7557 - y1_output_loss: 1.0659 - y2_output_loss: 2.6708 - y1_output_root_mean_squared_error: 1.0332 - y2_output_root_mean_squared_error: 1.6396 - val_loss: 2.7769 - val_y1_output_loss: 0.8752 - val_y2_output_loss: 1.8682 - val_y1_output_root_mean_squared_error: 0.9450 - val_y2_output_root_mean_squared_error: 1.3726
# Epoch 101/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.1421 - y1_output_loss: 0.5135 - y2_output_loss: 1.6632 - y1_output_root_mean_squared_error: 0.7150 - y2_output_root_mean_squared_error: 1.2770 - val_loss: 5.3246 - val_y1_output_loss: 0.9596 - val_y2_output_loss: 4.9300 - val_y1_output_root_mean_squared_error: 0.9446 - val_y2_output_root_mean_squared_error: 2.1053
# Epoch 102/500
# 614/614 [==============================] - 0s 122us/sample - loss: 3.3789 - y1_output_loss: 0.7929 - y2_output_loss: 2.8412 - y1_output_root_mean_squared_error: 0.8786 - y2_output_root_mean_squared_error: 1.6146 - val_loss: 68.6627 - val_y1_output_loss: 19.8295 - val_y2_output_loss: 59.6147 - val_y1_output_root_mean_squared_error: 4.1116 - val_y2_output_root_mean_squared_error: 7.1943
# Epoch 103/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.1038 - y1_output_loss: 1.3974 - y2_output_loss: 3.6686 - y1_output_root_mean_squared_error: 1.1843 - y2_output_root_mean_squared_error: 1.9239 - val_loss: 2.4023 - val_y1_output_loss: 0.7394 - val_y2_output_loss: 1.6935 - val_y1_output_root_mean_squared_error: 0.8424 - val_y2_output_root_mean_squared_error: 1.3010
# Epoch 104/500
# 614/614 [==============================] - 0s 135us/sample - loss: 1.9165 - y1_output_loss: 0.5173 - y2_output_loss: 1.3912 - y1_output_root_mean_squared_error: 0.7187 - y2_output_root_mean_squared_error: 1.1832 - val_loss: 2.7145 - val_y1_output_loss: 0.4231 - val_y2_output_loss: 2.2134 - val_y1_output_root_mean_squared_error: 0.6591 - val_y2_output_root_mean_squared_error: 1.5100
# Epoch 105/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.3305 - y1_output_loss: 0.5818 - y2_output_loss: 1.7297 - y1_output_root_mean_squared_error: 0.7649 - y2_output_root_mean_squared_error: 1.3212 - val_loss: 2.0663 - val_y1_output_loss: 0.5897 - val_y2_output_loss: 1.4324 - val_y1_output_root_mean_squared_error: 0.7637 - val_y2_output_root_mean_squared_error: 1.2178
# Epoch 106/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.2535 - y1_output_loss: 1.1072 - y2_output_loss: 3.1095 - y1_output_root_mean_squared_error: 1.0564 - y2_output_root_mean_squared_error: 1.7713 - val_loss: 2.3516 - val_y1_output_loss: 0.6053 - val_y2_output_loss: 1.7717 - val_y1_output_root_mean_squared_error: 0.7623 - val_y2_output_root_mean_squared_error: 1.3306
# Epoch 107/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.0392 - y1_output_loss: 0.4729 - y2_output_loss: 1.5561 - y1_output_root_mean_squared_error: 0.6854 - y2_output_root_mean_squared_error: 1.2528 - val_loss: 2.7602 - val_y1_output_loss: 0.4960 - val_y2_output_loss: 2.2009 - val_y1_output_root_mean_squared_error: 0.7084 - val_y2_output_root_mean_squared_error: 1.5028
# Epoch 108/500
# 614/614 [==============================] - 0s 140us/sample - loss: 1.9499 - y1_output_loss: 0.4968 - y2_output_loss: 1.4490 - y1_output_root_mean_squared_error: 0.7065 - y2_output_root_mean_squared_error: 1.2045 - val_loss: 2.4607 - val_y1_output_loss: 0.5175 - val_y2_output_loss: 1.9954 - val_y1_output_root_mean_squared_error: 0.7192 - val_y2_output_root_mean_squared_error: 1.3941
# Epoch 109/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.6766 - y1_output_loss: 0.6232 - y2_output_loss: 2.0305 - y1_output_root_mean_squared_error: 0.7924 - y2_output_root_mean_squared_error: 1.4313 - val_loss: 2.2776 - val_y1_output_loss: 0.6045 - val_y2_output_loss: 1.6936 - val_y1_output_root_mean_squared_error: 0.7780 - val_y2_output_root_mean_squared_error: 1.2932
# Epoch 110/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.1206 - y1_output_loss: 0.5300 - y2_output_loss: 1.5771 - y1_output_root_mean_squared_error: 0.7271 - y2_output_root_mean_squared_error: 1.2617 - val_loss: 1.8901 - val_y1_output_loss: 0.3743 - val_y2_output_loss: 1.4771 - val_y1_output_root_mean_squared_error: 0.6195 - val_y2_output_root_mean_squared_error: 1.2273
# Epoch 111/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.4570 - y1_output_loss: 0.5252 - y2_output_loss: 1.9227 - y1_output_root_mean_squared_error: 0.7275 - y2_output_root_mean_squared_error: 1.3885 - val_loss: 2.7970 - val_y1_output_loss: 0.4552 - val_y2_output_loss: 2.4871 - val_y1_output_root_mean_squared_error: 0.6724 - val_y2_output_root_mean_squared_error: 1.5313
# Epoch 112/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.8258 - y1_output_loss: 1.3910 - y2_output_loss: 3.4146 - y1_output_root_mean_squared_error: 1.1840 - y2_output_root_mean_squared_error: 1.8504 - val_loss: 2.5028 - val_y1_output_loss: 0.3822 - val_y2_output_loss: 2.2008 - val_y1_output_root_mean_squared_error: 0.6274 - val_y2_output_root_mean_squared_error: 1.4523
# Epoch 113/500
# 614/614 [==============================] - 0s 121us/sample - loss: 2.4769 - y1_output_loss: 0.6389 - y2_output_loss: 1.8455 - y1_output_root_mean_squared_error: 0.8014 - y2_output_root_mean_squared_error: 1.3545 - val_loss: 6.3322 - val_y1_output_loss: 1.0171 - val_y2_output_loss: 5.7674 - val_y1_output_root_mean_squared_error: 0.9897 - val_y2_output_root_mean_squared_error: 2.3136
# Epoch 114/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.4527 - y1_output_loss: 0.6325 - y2_output_loss: 1.8012 - y1_output_root_mean_squared_error: 0.7982 - y2_output_root_mean_squared_error: 1.3474 - val_loss: 2.2821 - val_y1_output_loss: 0.5134 - val_y2_output_loss: 1.7080 - val_y1_output_root_mean_squared_error: 0.7227 - val_y2_output_root_mean_squared_error: 1.3266
# Epoch 115/500
# 614/614 [==============================] - 0s 138us/sample - loss: 1.8236 - y1_output_loss: 0.4717 - y2_output_loss: 1.3630 - y1_output_root_mean_squared_error: 0.6827 - y2_output_root_mean_squared_error: 1.1652 - val_loss: 2.4541 - val_y1_output_loss: 0.7969 - val_y2_output_loss: 1.7238 - val_y1_output_root_mean_squared_error: 0.8636 - val_y2_output_root_mean_squared_error: 1.3071
# Epoch 116/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.7865 - y1_output_loss: 0.6885 - y2_output_loss: 2.0832 - y1_output_root_mean_squared_error: 0.8290 - y2_output_root_mean_squared_error: 1.4489 - val_loss: 2.1251 - val_y1_output_loss: 0.4601 - val_y2_output_loss: 1.6362 - val_y1_output_root_mean_squared_error: 0.6776 - val_y2_output_root_mean_squared_error: 1.2907
# Epoch 117/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.5010 - y1_output_loss: 0.5199 - y2_output_loss: 2.0053 - y1_output_root_mean_squared_error: 0.7176 - y2_output_root_mean_squared_error: 1.4093 - val_loss: 2.2646 - val_y1_output_loss: 0.4893 - val_y2_output_loss: 1.8426 - val_y1_output_root_mean_squared_error: 0.6982 - val_y2_output_root_mean_squared_error: 1.3330
# Epoch 118/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.3263 - y1_output_loss: 0.4620 - y2_output_loss: 1.8485 - y1_output_root_mean_squared_error: 0.6792 - y2_output_root_mean_squared_error: 1.3657 - val_loss: 1.8339 - val_y1_output_loss: 0.4118 - val_y2_output_loss: 1.3895 - val_y1_output_root_mean_squared_error: 0.6428 - val_y2_output_root_mean_squared_error: 1.1919
# Epoch 119/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.3317 - y1_output_loss: 1.9993 - y2_output_loss: 4.3010 - y1_output_root_mean_squared_error: 1.4198 - y2_output_root_mean_squared_error: 2.0774 - val_loss: 2.4892 - val_y1_output_loss: 0.5997 - val_y2_output_loss: 1.9303 - val_y1_output_root_mean_squared_error: 0.7785 - val_y2_output_root_mean_squared_error: 1.3723
# Epoch 120/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.2016 - y1_output_loss: 0.5413 - y2_output_loss: 1.6912 - y1_output_root_mean_squared_error: 0.7237 - y2_output_root_mean_squared_error: 1.2953 - val_loss: 6.9573 - val_y1_output_loss: 1.9102 - val_y2_output_loss: 5.4643 - val_y1_output_root_mean_squared_error: 1.2921 - val_y2_output_root_mean_squared_error: 2.2995
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.3673 - y1_output_loss: 0.1150 - y2_output_loss: 0.2502 - y1_output_root_mean_squared_error: 0.3399 - y2_output_root_mean_squared_error: 0.5018 - val_loss: 0.7759 - val_y1_output_loss: 0.1387 - val_y2_output_loss: 0.6154 - val_y1_output_root_mean_squared_error: 0.3779 - val_y2_output_root_mean_squared_error: 0.7957
# Epoch 462/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3551 - y1_output_loss: 0.1114 - y2_output_loss: 0.2421 - y1_output_root_mean_squared_error: 0.3347 - y2_output_root_mean_squared_error: 0.4931 - val_loss: 1.2351 - val_y1_output_loss: 0.2097 - val_y2_output_loss: 1.0211 - val_y1_output_root_mean_squared_error: 0.4479 - val_y2_output_root_mean_squared_error: 1.0171
# Epoch 463/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4160 - y1_output_loss: 0.1117 - y2_output_loss: 0.3011 - y1_output_root_mean_squared_error: 0.3353 - y2_output_root_mean_squared_error: 0.5509 - val_loss: 1.0787 - val_y1_output_loss: 0.1522 - val_y2_output_loss: 0.9048 - val_y1_output_root_mean_squared_error: 0.3931 - val_y2_output_root_mean_squared_error: 0.9613
# Epoch 464/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3230 - y1_output_loss: 0.1118 - y2_output_loss: 0.2094 - y1_output_root_mean_squared_error: 0.3340 - y2_output_root_mean_squared_error: 0.4598 - val_loss: 0.8377 - val_y1_output_loss: 0.2479 - val_y2_output_loss: 0.5923 - val_y1_output_root_mean_squared_error: 0.4765 - val_y2_output_root_mean_squared_error: 0.7815
# Epoch 465/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4160 - y1_output_loss: 0.1110 - y2_output_loss: 0.3018 - y1_output_root_mean_squared_error: 0.3346 - y2_output_root_mean_squared_error: 0.5514 - val_loss: 0.8919 - val_y1_output_loss: 0.1500 - val_y2_output_loss: 0.7235 - val_y1_output_root_mean_squared_error: 0.3885 - val_y2_output_root_mean_squared_error: 0.8608
# Epoch 466/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3579 - y1_output_loss: 0.1114 - y2_output_loss: 0.2473 - y1_output_root_mean_squared_error: 0.3352 - y2_output_root_mean_squared_error: 0.4955 - val_loss: 0.8421 - val_y1_output_loss: 0.1379 - val_y2_output_loss: 0.6970 - val_y1_output_root_mean_squared_error: 0.3756 - val_y2_output_root_mean_squared_error: 0.8373
# Epoch 467/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3381 - y1_output_loss: 0.1107 - y2_output_loss: 0.2250 - y1_output_root_mean_squared_error: 0.3338 - y2_output_root_mean_squared_error: 0.4761 - val_loss: 0.7610 - val_y1_output_loss: 0.1421 - val_y2_output_loss: 0.5972 - val_y1_output_root_mean_squared_error: 0.3805 - val_y2_output_root_mean_squared_error: 0.7850
# Epoch 468/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3743 - y1_output_loss: 0.1102 - y2_output_loss: 0.2664 - y1_output_root_mean_squared_error: 0.3297 - y2_output_root_mean_squared_error: 0.5154 - val_loss: 0.9171 - val_y1_output_loss: 0.3380 - val_y2_output_loss: 0.6057 - val_y1_output_root_mean_squared_error: 0.5430 - val_y2_output_root_mean_squared_error: 0.7888
# Epoch 469/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4176 - y1_output_loss: 0.1208 - y2_output_loss: 0.2938 - y1_output_root_mean_squared_error: 0.3489 - y2_output_root_mean_squared_error: 0.5440 - val_loss: 0.7917 - val_y1_output_loss: 0.1506 - val_y2_output_loss: 0.6327 - val_y1_output_root_mean_squared_error: 0.3907 - val_y2_output_root_mean_squared_error: 0.7994
# Epoch 470/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3849 - y1_output_loss: 0.1227 - y2_output_loss: 0.2625 - y1_output_root_mean_squared_error: 0.3513 - y2_output_root_mean_squared_error: 0.5114 - val_loss: 1.0524 - val_y1_output_loss: 0.2014 - val_y2_output_loss: 0.8508 - val_y1_output_root_mean_squared_error: 0.4478 - val_y2_output_root_mean_squared_error: 0.9230
# Epoch 471/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3920 - y1_output_loss: 0.1157 - y2_output_loss: 0.2842 - y1_output_root_mean_squared_error: 0.3377 - y2_output_root_mean_squared_error: 0.5272 - val_loss: 3.9728 - val_y1_output_loss: 0.7551 - val_y2_output_loss: 3.4461 - val_y1_output_root_mean_squared_error: 0.8022 - val_y2_output_root_mean_squared_error: 1.8247
# Epoch 472/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.6311 - y1_output_loss: 0.1323 - y2_output_loss: 0.4963 - y1_output_root_mean_squared_error: 0.3654 - y2_output_root_mean_squared_error: 0.7054 - val_loss: 1.2483 - val_y1_output_loss: 0.1963 - val_y2_output_loss: 1.0430 - val_y1_output_root_mean_squared_error: 0.4358 - val_y2_output_root_mean_squared_error: 1.0288
# Epoch 473/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.3550 - y1_output_loss: 0.1158 - y2_output_loss: 0.2419 - y1_output_root_mean_squared_error: 0.3404 - y2_output_root_mean_squared_error: 0.4890 - val_loss: 1.2222 - val_y1_output_loss: 0.1801 - val_y2_output_loss: 1.0738 - val_y1_output_root_mean_squared_error: 0.4291 - val_y2_output_root_mean_squared_error: 1.0189
# Epoch 474/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3762 - y1_output_loss: 0.1105 - y2_output_loss: 0.2637 - y1_output_root_mean_squared_error: 0.3338 - y2_output_root_mean_squared_error: 0.5145 - val_loss: 0.7376 - val_y1_output_loss: 0.1793 - val_y2_output_loss: 0.5502 - val_y1_output_root_mean_squared_error: 0.4153 - val_y2_output_root_mean_squared_error: 0.7518
# Epoch 475/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3255 - y1_output_loss: 0.1084 - y2_output_loss: 0.2186 - y1_output_root_mean_squared_error: 0.3287 - y2_output_root_mean_squared_error: 0.4664 - val_loss: 1.6907 - val_y1_output_loss: 0.3330 - val_y2_output_loss: 1.3811 - val_y1_output_root_mean_squared_error: 0.5557 - val_y2_output_root_mean_squared_error: 1.1755
# Epoch 476/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3367 - y1_output_loss: 0.1065 - y2_output_loss: 0.2279 - y1_output_root_mean_squared_error: 0.3275 - y2_output_root_mean_squared_error: 0.4791 - val_loss: 0.7260 - val_y1_output_loss: 0.1548 - val_y2_output_loss: 0.5581 - val_y1_output_root_mean_squared_error: 0.3972 - val_y2_output_root_mean_squared_error: 0.7538
# Epoch 477/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3650 - y1_output_loss: 0.1082 - y2_output_loss: 0.2556 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.5060 - val_loss: 0.8379 - val_y1_output_loss: 0.1489 - val_y2_output_loss: 0.6869 - val_y1_output_root_mean_squared_error: 0.3900 - val_y2_output_root_mean_squared_error: 0.8281
# Epoch 478/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3066 - y1_output_loss: 0.1110 - y2_output_loss: 0.1983 - y1_output_root_mean_squared_error: 0.3303 - y2_output_root_mean_squared_error: 0.4443 - val_loss: 1.1312 - val_y1_output_loss: 0.1922 - val_y2_output_loss: 0.9327 - val_y1_output_root_mean_squared_error: 0.4431 - val_y2_output_root_mean_squared_error: 0.9669
# Epoch 479/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4079 - y1_output_loss: 0.1139 - y2_output_loss: 0.2975 - y1_output_root_mean_squared_error: 0.3352 - y2_output_root_mean_squared_error: 0.5437 - val_loss: 1.0910 - val_y1_output_loss: 0.2147 - val_y2_output_loss: 0.8806 - val_y1_output_root_mean_squared_error: 0.4530 - val_y2_output_root_mean_squared_error: 0.9412
# Epoch 480/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4902 - y1_output_loss: 0.1369 - y2_output_loss: 0.3535 - y1_output_root_mean_squared_error: 0.3698 - y2_output_root_mean_squared_error: 0.5945 - val_loss: 0.8490 - val_y1_output_loss: 0.1514 - val_y2_output_loss: 0.6753 - val_y1_output_root_mean_squared_error: 0.3928 - val_y2_output_root_mean_squared_error: 0.8335
# Epoch 481/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4333 - y1_output_loss: 0.1226 - y2_output_loss: 0.3120 - y1_output_root_mean_squared_error: 0.3498 - y2_output_root_mean_squared_error: 0.5576 - val_loss: 1.2902 - val_y1_output_loss: 0.4683 - val_y2_output_loss: 0.8637 - val_y1_output_root_mean_squared_error: 0.6474 - val_y2_output_root_mean_squared_error: 0.9334
# Epoch 482/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4622 - y1_output_loss: 0.1281 - y2_output_loss: 0.3323 - y1_output_root_mean_squared_error: 0.3586 - y2_output_root_mean_squared_error: 0.5776 - val_loss: 1.2964 - val_y1_output_loss: 0.2398 - val_y2_output_loss: 1.0694 - val_y1_output_root_mean_squared_error: 0.4738 - val_y2_output_root_mean_squared_error: 1.0353
# Epoch 483/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3300 - y1_output_loss: 0.1119 - y2_output_loss: 0.2185 - y1_output_root_mean_squared_error: 0.3352 - y2_output_root_mean_squared_error: 0.4665 - val_loss: 0.8398 - val_y1_output_loss: 0.2129 - val_y2_output_loss: 0.6322 - val_y1_output_root_mean_squared_error: 0.4449 - val_y2_output_root_mean_squared_error: 0.8012
# Epoch 484/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.3949 - y1_output_loss: 0.1214 - y2_output_loss: 0.2703 - y1_output_root_mean_squared_error: 0.3498 - y2_output_root_mean_squared_error: 0.5221 - val_loss: 0.7887 - val_y1_output_loss: 0.1744 - val_y2_output_loss: 0.6041 - val_y1_output_root_mean_squared_error: 0.4082 - val_y2_output_root_mean_squared_error: 0.7887
# Epoch 485/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.9262 - y1_output_loss: 0.1654 - y2_output_loss: 0.7568 - y1_output_root_mean_squared_error: 0.4060 - y2_output_root_mean_squared_error: 0.8725 - val_loss: 1.2981 - val_y1_output_loss: 0.2460 - val_y2_output_loss: 1.1024 - val_y1_output_root_mean_squared_error: 0.4911 - val_y2_output_root_mean_squared_error: 1.0281
# Epoch 486/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4124 - y1_output_loss: 0.1451 - y2_output_loss: 0.2747 - y1_output_root_mean_squared_error: 0.3746 - y2_output_root_mean_squared_error: 0.5217 - val_loss: 1.5174 - val_y1_output_loss: 0.3460 - val_y2_output_loss: 1.1989 - val_y1_output_root_mean_squared_error: 0.5842 - val_y2_output_root_mean_squared_error: 1.0845
# Epoch 487/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.5401 - y1_output_loss: 0.1523 - y2_output_loss: 0.3843 - y1_output_root_mean_squared_error: 0.3916 - y2_output_root_mean_squared_error: 0.6219 - val_loss: 0.7660 - val_y1_output_loss: 0.1548 - val_y2_output_loss: 0.5944 - val_y1_output_root_mean_squared_error: 0.3935 - val_y2_output_root_mean_squared_error: 0.7818
# Epoch 488/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4737 - y1_output_loss: 0.1237 - y2_output_loss: 0.3480 - y1_output_root_mean_squared_error: 0.3517 - y2_output_root_mean_squared_error: 0.5916 - val_loss: 0.7469 - val_y1_output_loss: 0.1588 - val_y2_output_loss: 0.5861 - val_y1_output_root_mean_squared_error: 0.4004 - val_y2_output_root_mean_squared_error: 0.7659
# Epoch 489/500
# 614/614 [==============================] - 0s 121us/sample - loss: 0.4600 - y1_output_loss: 0.1193 - y2_output_loss: 0.3390 - y1_output_root_mean_squared_error: 0.3439 - y2_output_root_mean_squared_error: 0.5846 - val_loss: 0.8644 - val_y1_output_loss: 0.2025 - val_y2_output_loss: 0.6993 - val_y1_output_root_mean_squared_error: 0.4461 - val_y2_output_root_mean_squared_error: 0.8157
# Epoch 490/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4932 - y1_output_loss: 0.1398 - y2_output_loss: 0.3508 - y1_output_root_mean_squared_error: 0.3743 - y2_output_root_mean_squared_error: 0.5942 - val_loss: 0.7415 - val_y1_output_loss: 0.1591 - val_y2_output_loss: 0.5768 - val_y1_output_root_mean_squared_error: 0.3958 - val_y2_output_root_mean_squared_error: 0.7648
# Epoch 491/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3170 - y1_output_loss: 0.1151 - y2_output_loss: 0.2047 - y1_output_root_mean_squared_error: 0.3378 - y2_output_root_mean_squared_error: 0.4504 - val_loss: 0.8643 - val_y1_output_loss: 0.1991 - val_y2_output_loss: 0.6643 - val_y1_output_root_mean_squared_error: 0.4389 - val_y2_output_root_mean_squared_error: 0.8195
# Epoch 492/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3602 - y1_output_loss: 0.1082 - y2_output_loss: 0.2491 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.5012 - val_loss: 0.8777 - val_y1_output_loss: 0.1796 - val_y2_output_loss: 0.6921 - val_y1_output_root_mean_squared_error: 0.4165 - val_y2_output_root_mean_squared_error: 0.8392
# Epoch 493/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.3587 - y1_output_loss: 0.1063 - y2_output_loss: 0.2521 - y1_output_root_mean_squared_error: 0.3262 - y2_output_root_mean_squared_error: 0.5022 - val_loss: 1.0886 - val_y1_output_loss: 0.1792 - val_y2_output_loss: 0.9013 - val_y1_output_root_mean_squared_error: 0.4202 - val_y2_output_root_mean_squared_error: 0.9550
# Epoch 494/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3067 - y1_output_loss: 0.1091 - y2_output_loss: 0.1951 - y1_output_root_mean_squared_error: 0.3316 - y2_output_root_mean_squared_error: 0.4436 - val_loss: 0.7204 - val_y1_output_loss: 0.1550 - val_y2_output_loss: 0.5518 - val_y1_output_root_mean_squared_error: 0.3955 - val_y2_output_root_mean_squared_error: 0.7509
# Epoch 495/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.2967 - y1_output_loss: 0.1039 - y2_output_loss: 0.1930 - y1_output_root_mean_squared_error: 0.3230 - y2_output_root_mean_squared_error: 0.4386 - val_loss: 1.0749 - val_y1_output_loss: 0.2435 - val_y2_output_loss: 0.8638 - val_y1_output_root_mean_squared_error: 0.4674 - val_y2_output_root_mean_squared_error: 0.9254
# Epoch 496/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3171 - y1_output_loss: 0.1033 - y2_output_loss: 0.2114 - y1_output_root_mean_squared_error: 0.3223 - y2_output_root_mean_squared_error: 0.4617 - val_loss: 0.6969 - val_y1_output_loss: 0.1457 - val_y2_output_loss: 0.5513 - val_y1_output_root_mean_squared_error: 0.3800 - val_y2_output_root_mean_squared_error: 0.7433
# Epoch 497/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4005 - y1_output_loss: 0.1170 - y2_output_loss: 0.2829 - y1_output_root_mean_squared_error: 0.3433 - y2_output_root_mean_squared_error: 0.5316 - val_loss: 0.7462 - val_y1_output_loss: 0.1496 - val_y2_output_loss: 0.6124 - val_y1_output_root_mean_squared_error: 0.3903 - val_y2_output_root_mean_squared_error: 0.7706
# Epoch 498/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3512 - y1_output_loss: 0.1078 - y2_output_loss: 0.2411 - y1_output_root_mean_squared_error: 0.3289 - y2_output_root_mean_squared_error: 0.4929 - val_loss: 0.7224 - val_y1_output_loss: 0.1469 - val_y2_output_loss: 0.5714 - val_y1_output_root_mean_squared_error: 0.3870 - val_y2_output_root_mean_squared_error: 0.7567
# Epoch 499/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3103 - y1_output_loss: 0.1081 - y2_output_loss: 0.2022 - y1_output_root_mean_squared_error: 0.3289 - y2_output_root_mean_squared_error: 0.4496 - val_loss: 0.8090 - val_y1_output_loss: 0.1604 - val_y2_output_loss: 0.6345 - val_y1_output_root_mean_squared_error: 0.3942 - val_y2_output_root_mean_squared_error: 0.8085
# Epoch 500/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.2930 - y1_output_loss: 0.1037 - y2_output_loss: 0.1878 - y1_output_root_mean_squared_error: 0.3228 - y2_output_root_mean_squared_error: 0.4345 - val_loss: 0.8321 - val_y1_output_loss: 0.1669 - val_y2_output_loss: 0.6659 - val_y1_output_root_mean_squared_error: 0.4004 - val_y2_output_root_mean_squared_error: 0.8196

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 30us/sample - loss: 0.8321 - y1_output_loss: 0.1600 - y2_output_loss: 0.6668 - y1_output_root_mean_squared_error: 0.4004 - y2_output_root_mean_squared_error: 0.8196
# Loss = 0.8320655729863551, Y1_loss = 0.15998157858848572, Y1_mse = 0.4003605246543884, Y2_loss = 0.666824460029602, Y2_mse = 0.8196200132369995

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
